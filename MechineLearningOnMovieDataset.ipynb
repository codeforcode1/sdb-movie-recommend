# %% [markdown]
# # Movie Recomanded system

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies = movies.merge(credits,on = 'title')

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
movies.shape
# Out:
# (4809, 23)

# %%
movies.head(1)['genres'].values
# Out:
# array(['[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'],
#       dtype=object)

# %% [markdown]
# <h2> To take the genres, id, keywords, title, overview, revenue, vote_average, cast </h2>

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
movies = movies[['title','genres','id','keywords','overview','revenue','vote_average','cast', 'crew']]

# %%
movies.head(1)
# Out:
#     title                                             genres     id  \
# 0  Avatar  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                             overview     revenue  \
# 0  In the 22nd century, a paraplegic Marine is di...  2787965087
#
#    vote_average                                               cast  \
# 0           7.2  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies = movies.dropna()

# %%
 movies.iloc[0]['genres']
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast

# %%
def convert(obj):
    li=[]
    for i in ast.literal_eval(obj):
        li.append(i['name'])
    return li

# %%
movies['genres'] = movies['genres'].apply(convert)

# %%
movies.head(1)
# Out:
#     title                                         genres     id  \
# 0  Avatar  [Action, Adventure, Fantasy, Science Fiction]  19995
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                             overview     revenue  \
# 0  In the 22nd century, a paraplegic Marine is di...  2787965087
#
#    vote_average                                               cast  \
# 0           7.2  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies.iloc[0]['keywords']
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies['keywords'] = movies['keywords'].apply(convert)

# %%
movies.head(1)
# Out:
#     title                                         genres     id  \
# 0  Avatar  [Action, Adventure, Fantasy, Science Fiction]  19995
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview     revenue  \
# 0  In the 22nd century, a paraplegic Marine is di...  2787965087
#
#    vote_average                                               cast  \
# 0           7.2  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies.iloc[0]['cast']
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
def castmain(obj):
#     for i in range(3):
    j=0
    li=[]
    for i in ast.literal_eval(obj):
        li.append(i['name'])
        j=j+1
        if(j==3):
            break
    return li

# %%
castmain(movies.iloc[0]['cast'])
# Out:
# ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver']

# %%
movies['cast'] = movies['cast'].apply(castmain)

# %%
movies.iloc[0]['crew']
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
def find_director(obj):
    l=[]
    for i in ast.literal_eval(obj):
        if i['job']=='Director':
            l.append(i['name'])
            break
    return l

# %%
find_director(movies.iloc[0]['crew'])
# Out:
# ['James Cameron']

# %%
movies['crew'] = movies['crew'].apply(find_director)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4806 entries, 0 to 4808
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         4806 non-null   object
#  1   genres        4806 non-null   object
#  2   id            4806 non-null   int64
#  3   keywords      4806 non-null   object
#  4   overview      4806 non-null   object
#  5   revenue       4806 non-null   int64
#  6   vote_average  4806 non-null   float64
#  7   cast          4806 non-null   object
#  8   crew          4806 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 375.5+ KB

# %%
movies.iloc[0]['overview']
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
# ...

# %%
def space(obj):
    l=[]
    for i in obj:
#         print(i,type(i))
        l.append(i.replace(' ',''))
    return l

# %%
def co(obj):
    l=[]
    for i in obj:
#         print(i,type(i))
        l.append(i.replace(' ',','))
    return l

# %%
movies['cast'] = movies['cast'].apply(space)
movies['keywords'] = movies['keywords'].apply(space)
movies['overview'] = movies['overview'].apply(co)
movies['crew'] = movies['crew'].apply(space)

# %%
movies.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
# ...

# %%
movies['all_tags'] = movies['overview'] + movies['keywords'] + movies['cast'] + movies['crew'] + movies['genres'] #movies['vote_average']

# %%
movies.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
# ...

# %%
df = movies[['id','title','vote_average','all_tags']]

# %%
df.head()
# Out:
#        id                                     title  vote_average  \
# 0   19995                                    Avatar           7.2
# 1     285  Pirates of the Caribbean: At World's End           6.9
# 2  206647                                   Spectre           6.3
# 3   49026                     The Dark Knight Rises           7.6
# 4   49529                               John Carter           6.1
#
#                                             all_tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
df['all_tags'] = df['all_tags'].apply(lambda x:' '.join(x))
# Out:
# C:\Users\COMPUTER\AppData\Local\Temp\ipykernel_3120\405021296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['all_tags'] = df['all_tags'].apply(lambda x:' '.join(x))

# %%
df.head()
# Out:
#        id                                     title  vote_average  \
# 0   19995                                    Avatar           7.2
# 1     285  Pirates of the Caribbean: At World's End           6.9
# 2  206647                                   Spectre           6.3
# 3   49026                     The Dark Knight Rises           7.6
# 4   49529                               John Carter           6.1
#
#                                             all_tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
df['all_tags'] = df['all_tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\COMPUTER\AppData\Local\Temp\ipykernel_3120\1787592503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['all_tags'] = df['all_tags'].apply(lambda x:x.lower())

# %%
df.head()
# Out:
#        id                                     title  vote_average  \
# 0   19995                                    Avatar           7.2
# 1     285  Pirates of the Caribbean: At World's End           6.9
# 2  206647                                   Spectre           6.3
# 3   49026                     The Dark Knight Rises           7.6
# 4   49529                               John Carter           6.1
#
#                                             all_tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

# %%
def stemming(obj):
    l=[]
    for i in obj.split():
        l.append(ps.stem(i))
    return ' '.join(l)

# %%
stemming(df.iloc[0]['all_tags'])
# Out:
# 'in the 22nd century, a parapleg marin is dispatch to the moon pandora on a uniqu mission, but becom torn between follow order and protect an alien civilization. cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d samworthington zoesaldana sigourneyweav jamescameron action adventur fantasi scienc fiction'

# %%
df['all_tags'] = df['all_tags'].apply(stemming)
# Out:
# C:\Users\COMPUTER\AppData\Local\Temp\ipykernel_3120\1399531080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['all_tags'] = df['all_tags'].apply(stemming)

# %%
df.shape
# Out:
# (4806, 4)

# %%
df = df.drop_duplicates(subset=['vote_average','title','id'])

# %%
df.shape
# Out:
# (4800, 4)

# %%
from sklearn.feature_extraction.text import CountVectorizer
countvec = CountVectorizer(max_features=10000,stop_words='english')
vector = countvec.fit_transform(df['all_tags']).toarray()

# %%
countvec.get_feature_names()
# Out:
# C:\Users\COMPUTER\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00',
#  '000',
#  '007',
#  '10',
#  '100',
#  '10th',
#  '11',
#  '12',
#  '12th',
#  '13',
#  '14',
#  '15',
#  '150',
#  '15th',
#  '16',
#  '16th',
#  '17',
#  '17th',
#  '18',
#  '1863',
#  '1890',
#  '18th',
#  '18thcenturi',
#  '19',
#  '1910',
#  '1920',
#  '1927',
#  '1930',
#  '1930s',
#  '1937',
#  '1940',
#  '1940s',
#  '1941',
#  '1944',
#  '1945',
#  '1950',
#  '1950s',
#  '1955',
#  '1959',
#  '1960',
#  '1960s',
#  '1962',
#  '1964',
#  '1965',
#  '1967',
#  '1969',
#  '1970',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1976',
#  '1977',
#  '1979',
#  '1980',
#  '1980s',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1990',
#  '1994',
#  '1995',
#  '1996',
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity  = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.07118685, 0.07426107, ..., 0.03892495, 0.        ,
#         0.        ],
#        [0.07118685, 1.        , 0.05638839, ..., 0.02216755, 0.        ,
#         0.02450715],
#        [0.07426107, 0.05638839, 1.        , ..., 0.02312486, 0.        ,
#         0.        ],
#        ...,
#        [0.03892495, 0.02216755, 0.02312486, ..., 1.        , 0.03739788,
#         0.04020151],
#        [0.        , 0.        , 0.        , ..., 0.03739788, 1.        ,
#         0.08268982],
#        [0.        , 0.02450715, 0.        , ..., 0.04020151, 0.08268982,
#         1.        ]])

# %%
df.head(2)
# Out:
#       id                                     title  vote_average  \
# 0  19995                                    Avatar           7.2
# 1    285  Pirates of the Caribbean: At World's End           6.9
#
#                                             all_tags
# 0  in the 22nd century, a parapleg marin is dispa...
# 1  captain barbossa, long believ to be dead, ha c...

# %%
similarity.shape
# Out:
# (4800, 4800)

# %%
similarity[0][1],df.iloc[0][2],df.iloc[1][2]
# Out:
# (0.07118684968143743, 7.2, 6.9)

# %%
type(len(similarity[0]))
# Out:
# int

# %%
vote = np.array(df['vote_average'])
vote[0]
# Out:
# 7.2

# %%
similarity = np.array(similarity)
similarity
# Out:
# array([[1.        , 0.07118685, 0.07426107, ..., 0.03892495, 0.        ,
#         0.        ],
#        [0.07118685, 1.        , 0.05638839, ..., 0.02216755, 0.        ,
#         0.02450715],
#        [0.07426107, 0.05638839, 1.        , ..., 0.02312486, 0.        ,
#         0.        ],
#        ...,
#        [0.03892495, 0.02216755, 0.02312486, ..., 1.        , 0.03739788,
#         0.04020151],
#        [0.        , 0.        , 0.        , ..., 0.03739788, 1.        ,
#         0.08268982],
#        [0.        , 0.02450715, 0.        , ..., 0.04020151, 0.08268982,
#         1.        ]])

# %%
n= len(similarity[0])
sim=  np.ones((n,n))
for i in range(n):
    for j in range(n):
        sim[i][j]=similarity[i][j]*vote[i]*vote[j]

# %%
sim
# Out:
# array([[51.84      ,  3.53656269,  3.36848194, ...,  1.96181734,
#          0.        ,  0.        ],
#        [ 3.53656269, 47.61      ,  2.4512032 , ...,  1.0706929 ,
#          0.        ,  1.06532599],
#        [ 3.36848194,  2.4512032 , 39.69      , ...,  1.01980652,
#          0.        ,  0.        ],
#        ...,
#        [ 1.96181734,  1.0706929 ,  1.01980652, ..., 49.        ,
#          1.4921754 ,  1.77288671],
#        [ 0.        ,  0.        ,  0.        , ...,  1.4921754 ,
#         32.49      ,  2.96939155],
#        [ 0.        ,  1.06532599,  0.        , ...,  1.77288671,
#          2.96939155, 39.69      ]])

# %%
sorted(list( enumerate(sim[1])),reverse=True,key=lambda x:x[1])[1:6]
# Out:
# [(12, 19.851177717121896),
#  (199, 14.888383287841421),
#  (17, 11.12257407500863),
#  (216, 8.662774039189413),
#  (3568, 8.18150881479)]

# %%
def find_index(obj, id):
    recomanded = sorted(list( enumerate(obj[id])),reverse=True,key=lambda x:x[1])[1:6]
    l=[]
    for i in recomanded:
        l.append(i[0])
    return l

# %%
find_index(sim,1)
# Out:
# [12, 199, 17, 216, 3568]

# %%
df.iloc[1360:1370,:]
# Out:
#          id                          title  vote_average  \
# 1362    268                         Batman           7.0
# 1364   2661                         Batman           6.1
# 1366  45054               There Be Dragons           5.9
# 1367    943                Lethal Weapon 3           6.4
# 1368  22881                 The Blind Side           7.2
# 1369  10054                       Spy Kids           5.5
# 1370  51540                Horrible Bosses           6.5
# 1371  44264                      True Grit           7.2
# 1372    350          The Devil Wears Prada           7.0
# 1373    152  Star Trek: The Motion Picture           6.2
#
#                                                all_tags
# 1362  the dark knight of gotham citi begin hi war on...
# 1364  the dynam duo face four super-villain who plan...
# 1366  aris out of the horror of the spanish civil wa...
# 1367  archetyp buddi cop rigg and murtaugh are back ...
# ...

# %%
def sim_movies(title, check = True):
    for i in range(len(sim[0])):
        if df.iloc[i,1].lower()==title.lower():
            k=i
            break
#     index = df[df['title']==title]
    if check==True:
        flag=sim
    else:
        flag=similarity
    similar_movie_index = find_index(flag,k)
    l=[]
    for i in similar_movie_index:
        l.append(df.iloc[i,1])
    return l

# %%
sim_movies('iron man')
# Out:
# ['Iron Man 3',
#  'Iron Man 2',
#  'Avengers: Age of Ultron',
#  'The Avengers',
#  'Guardians of the Galaxy']

# %%
sim_movies('iron man',0)
# Out:
# ['Iron Man 3',
#  'Iron Man 2',
#  'Avengers: Age of Ultron',
#  'The Avengers',
#  'The Helix... Loaded']

# %%
import pickle

# %%
pickle.dump(df,open('movie_data.pkl','wb'))

# %%
pickle.dump(similarity,open('sim_good.pkl','wb'))

# %%
pickle.dump(sim,open('sim_best.pkl','wb'))

# %%
mov= 'Batman'
index = df[df['title']==mov].iloc[0,0]
index
# Out:
# 268
